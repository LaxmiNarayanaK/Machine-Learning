# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import norm
domain = np.linspace(0,10,10,False)
plt.plot(domain,norm.pdf(domain,5,1),"go-")

# %%
import math
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import norm
s=np.linspace(0,10,10)
N=10
def likelihood(domain):
    i=0
    sum=0
    while(i<N):
        sum+=pow(s[i]-domain,2)
        i=i+1
    a=-0.5*sum-(N/2)*(math.log(2*3.14))
    return a
b = np.vectorize(likelihood)
domain=np.linspace(0,10,10)
plt.plot(domain,b(domain))
plt.plot(domain,b(domain),'go-')
